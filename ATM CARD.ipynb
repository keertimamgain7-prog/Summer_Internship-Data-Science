# %%
###### print('WELCOME TO PUNJAB NATIONAL BANK')
print("ATM CARD")
ACCOUNT_NUMBER="1234567ABD"
PIN=12345
BALANCE=5000

ACCOUNT_NUMBER_ENTERED=(input("Enter account no."))
PIN_ENTERED=int(input("Enter pin"))
if ACCOUNT_NUMBER==ACCOUNT_NUMBER_ENTERED and PIN==PIN_ENTERED:
     print("Login succesfull")
     while True:
        print("\n ATM login ")
        print("1. Balance check \n")
        print("2. Deposit money \n")
        print("3. Withdraw money \n")
        print("4. Change PIN \n")
        print("5. Display card details \n")
        print("6. EXIT")

        choice=int(input("Enter your Choice"))
        if choice == 1:
            print("Current Balance available in account",BALANCE)
        elif choice == 2:
            amount_deposited=int(input("Enter the amount to be deposited :"))
            new_Balance= BALANCE + amount_deposited
            print("Balance after money is deposited in account:",new_Balance)
            print("AMOUNT DEPOSITED SUCCESFULLY")
        elif choice == 3:
            amount_withdrawn=int(input("Enter the amount to be withdrawn :"))
            BALANCE=BALANCE-amount_withdrawn
            print(" New balance of the account:",BALANCE)
        elif choice == 4:
            new_pin=int(input("Enter the changed pin:"))
            PIN= new_pin
            print("Changed PIN of the account",PIN)
        elif choice == 5:
            print("Card details are as follows: \n", "Account number:",ACCOUNT_NUMBER,"\n","Balance:",BALANCE)
        elif choice==6:
            print("Exit")
            break
        else:
            print("THANKYOU FOR USING THE ATM SERVICES")
# Out:
# ATM CARD
# Enter account no. 1234567ABD
# Enter pin 12345
# Login succesfull
#
#  ATM login
# 1. Balance check
#
# 2. Deposit money
#
# 3. Withdraw money
#
# 4. Change PIN
#
# 5. Display card details
#
# 6. EXIT
# Enter your Choice 1
# Current Balance available in account 5000
#
#  ATM login
# 1. Balance check
#
# 2. Deposit money
#
# 3. Withdraw money
#
# 4. Change PIN
#
# 5. Display card details
#
# 6. EXIT
# Enter your Choice 2
# Enter the amount to be deposited : 4000
# Balance after money is deposited in account: 9000
# AMOUNT DEPOSITED SUCCESFULLY
#
#  ATM login
# 1. Balance check
#
# 2. Deposit money
#
# 3. Withdraw money
#
# 4. Change PIN
#
# 5. Display card details
#
# 6. EXIT
# Enter your Choice 4
# Enter the changed pin: 2378
# Changed PIN of the account 2378
#
#  ATM login
# 1. Balance check
#
# 2. Deposit money
#
# 3. Withdraw money
#
# 4. Change PIN
#
# 5. Display card details
#
# 6. EXIT
# Enter your Choice 6
# Exit
