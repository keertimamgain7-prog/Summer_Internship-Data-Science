# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img=Image.open(r"C:\Users\prash\Desktop\BUTTERFLY.jpeg")

img=np.array(img)
img[:, :,0]=np.clip(img[:,:,0]+ 90,100,0)

plt.imshow(img)
plt.axis("off")
plt.show()
